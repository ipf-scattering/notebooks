# %%
## load pylab, forthe sf.* interactive functions you have to 
## use a GUI backend: osx, qt5 and tk work; gtk and wx should also work

#%pylab osx
# %pylab qt5
#%pylab tk
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from ipychord3 import sf, utils

# %%
p = utils.TestPattern().make_pattern(0)

# %%
sf.show(p)

# %%
harmonized = sf.harmony(p, p['beam_position'])

# %%
sf.show(harmonized)
